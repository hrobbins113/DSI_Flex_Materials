# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression

pd.options.display.max_columns = 100
pd.options.display.max_rows = 3000

# %%
df = pd.read_csv('data/titanic_train.csv')
df_test = pd.read_csv('data/titanic_test.csv')

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df[df[('Neighborhood' = 'Timber') & (SalePrice >= 5)]]

# %%
filter = df.where(driver_name='Matt"&&distance>=5)
new_df = df.where(filter)

# %%
d = df.where(Neighborhood='Timber"& SalePrice >=5)
# new_df = df.where(filter)
# Out:
#   File "<ipython-input-44-45b52b21131b>", line 1
#     d = df.where(Neighborhood='Timber"& SalePrice >=5)
#                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
df[ (df['Neighborhood'] == 'Timber') & (df['SalePrice'] > 5) ]
# Out:
# Empty DataFrame
# ...

# %%
df[(df.Neighborhood == 'Timber') & (df.SalePrice >= 5.0)]
# Out:
# Empty DataFrame
# ...

# %%
df[(df['Neighborhood'] == 'Sawyer') & (df['Lot Area'] <= 15000) ]
# Out:
# Empty DataFrame
# ...

# %%
df['MS Zoning'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Series([], Name: MS Zoning, dtype: object)>

# %%
df[(df['driver_name'] == 'Matt') & (df['distance'] <= 5) ]
# Out:
#   File "<ipython-input-36-85ea7224bb4e>", line 1
#     df[[Electrical ='SBrkr' & Fireplaces < 1]]
#                    ^
# SyntaxError: invalid syntax

# %%
df.dropna(inplace = True)

# %%
df[(Neighborhood == 'Sawyer') & (Lot Area >= 5) ]
# Out:
#   File "<ipython-input-33-cdd0662ef399>", line 1
#     df[(Neighborhood == 'Sawyer') & (Lot Area >= 5) ]
#                                             ^
# SyntaxError: invalid syntax

# %%
df[(Neighborhood == 'Matt') & (Fireplaces < 5) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-55b04e073960> in <module>
# ----> 1 df[(Neighborhood == 'Matt') & (Fireplaces < 5) ]
#
# NameError: name 'Neighborhood' is not defined

# %%
df[[df[['Neighborhood'] == 'Sawyer']]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/env3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-154437828ac8> in <module>
# ----> 1 df[[df[['Neighborhood'] == 'Sawyer']]]
#
# ...

# %%
df[(df['Neighborhood'] == 'Sawyer')]
#    & (df['Lot Area'] >= 10.0)]
# Out:
# Empty DataFrame
# ...

# %%
'Neighborhood' == 'Sawyer'

# %% [markdown]
# #### SLR Model

# %%
X_train=
y_train =

# %% [markdown]
# #### Wait, was the heck does that score mean?
#     - The score is the R2 score, otherwise known as the coefficient of determination.
#     - In statistics, the coefficient of determination, denoted R2 or r2 and pronounced "R squared", is the proportion of the variance in the dependent variable that is predictable from the independent variable(s).
#     - It's typically between 0.0-1.0
#     - You may occasionally see a negative R2 score, but that means that something is very very wrong with your
#     model

# %% [markdown]
# #### Now we have a model object, and we can run our test data through it

# %%
#Recall test dataframe
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %% [markdown]
# #### Now we have a crappy model and want to make a submission!

# %%
#this is the format we want our submissions to be in: 

sample_sub = pd.read_csv('sample_sub_reg.csv')

# %%
sample_sub.head()
# Out:
#    Id    SalePrice
# 0   2  181479.1217
# 1   4  181479.1217
# 2   6  181479.1217
# 3   7  181479.1217
# 4  17  181479.1217

# %%
my_crappy_submission = pd.DataFrame({'Id' : df_test['Id'],
                           'SalePrice' : df_test['y_hat']})

# %%
my_crappy_submission.head()
# Out:
#      Id      SalePrice
# 0  2658  177210.726787
# 1  2718  292426.241137
# 2  2414  132681.816277
# 3  1989  170884.214911
# 4   625  222712.946815

# %%
crappy_submission.to_csv('crappy_submission.csv', index=False)

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Intro to `pandas` Review
#
#
# ---

# %% [markdown]
# Load the following libraries (**Use their common aliases**):
# - pandas
# - matplotlib.pyplot
# - seaborn
#
# Also, be sure to add the `%matplotlib inline` command so that your plots show in Jupyter automatically.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### A. Explore TV Cast Data
#
# ---
#
# #### Load the `tv-cast.csv` data into a `pandas` DataFrame (In the `datasets` directory).

# %% [markdown]
# #### Print the head and tail of the data.

# %%
# Out:
#           Performer          Show  Show Start Show End Status?  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010     END     2000
# 1    Kelli Williams  The Practice        1997     2014     END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014     END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014     END     2003
# 4   Dylan McDermott  The Practice        1997     2014     END     2004
#
#    Years Since  #LEAD  #SUPPORT  #Shows  Score      Score/Y  \
# 0           15      0         0       0   0.00            0
# 1           12      0         1       6   6.25  0.520833333
# 2           12      2         0       2   4.00  0.333333333
# 3           12      0         0       0   0.00            0
# 4           11      2         7       6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
# Out:
#            Performer             Show  Show Start Show End Status?  CharEnd  \
# 243     Meghan Wolfe   True Detective        2014  PRESENT    LEFT     2014
# 244       Kevin Dunn   True Detective        2014  PRESENT    LEFT     2014
# 245    Charles Dance  Game of Thrones        2011  PRESENT    LEFT     2015
# 246  Patrick Dempsey   Grey's Anatomy        2005  PRESENT    LEFT     2015
# 247   Ian McElhinney  Game of Thrones        2011  PRESENT    LEFT     2015
#
#      Years Since  #LEAD  #SUPPORT  #Shows  Score  Score/Y lead_notes  \
# 243            1      0         0       0   0.00        0        NaN
# 244            1      0         1       2   2.25     2.25        NaN
# 245            0      0         2       1   1.50  #DIV/0!        NaN
# 246            0      0         0       0   0.00  #DIV/0!        NaN
# 247            0      0         0       0   0.00  #DIV/0!        NaN
#
#                            support_notes                    show_notes
# ...

# %% [markdown]
# ####  Print the columns of the data.

# %%
df.columns
# Out:
# Index(['Performer', 'Show', 'Show Start', 'Show End', 'Status?', 'CharEnd',
#        'Years Since', '#LEAD', '#SUPPORT', '#Shows', 'Score', 'Score/Y',
#        'lead_notes', 'support_notes', 'show_notes'],
#       dtype='object')

# %% [markdown]
# #### Modify the column names so there aren't any spaces or special characters

# %%
df.columns = ['Performer', 'Show', 'Show_Start', 'Show_End', 'Status', 'CharEnd',
       'Years_Since', 'LEAD', 'SUPPORT', 'Shows', 'Score', 'ScoreY',
       'lead_notes', 'support_notes', 'show_notes']

# %%
# Out:
#           Performer          Show  Show_Start Show_End Status  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010    END     2000
# 1    Kelli Williams  The Practice        1997     2014    END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014    END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014    END     2003
# 4   Dylan McDermott  The Practice        1997     2014    END     2004
#
#    Years_Since  LEAD  SUPPORT  Shows  Score       ScoreY  \
# 0           15     0        0      0   0.00            0
# 1           12     0        1      6   6.25  0.520833333
# 2           12     2        0      2   4.00  0.333333333
# 3           12     0        0      0   0.00            0
# 4           11     2        7      6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# 2  Life of a King, 2014; Go For Sisters, 2013
# ...

# %%
#if you want it all in lower case
df.rename(str.lower, axis='columns', inplace =True)

# %%
# Out:
#           performer          show  show_start show_end status  charend  \
# 0       Steven Hill   Law & Order        1990     2010    END     2000
# 1    Kelli Williams  The Practice        1997     2014    END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014    END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014    END     2003
# 4   Dylan McDermott  The Practice        1997     2014    END     2004
#
#    years_since  lead  support  shows  score       scorey  \
# 0           15     0        0      0   0.00            0
# 1           12     0        1      6   6.25  0.520833333
# 2           12     2        0      2   4.00  0.333333333
# 3           12     0        0      0   0.00            0
# 4           11     2        7      6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# 2  Life of a King, 2014; Go For Sisters, 2013
# ...

# %% [markdown]
# ####  [Rename any columns](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html) with spaces or special characters to not contain any.

# %%
df.rename(index=str, columns={"Show Start": "Show_start", "Show End": "Show_End", "Status?": "Status", "#LEAD": "Lead",
                             "#SUPPORT": "Support", "#Shows": "Shows", "Score/Y": "Score"}, inplace = True)

# %%
df.columns
# Out:
# Index(['performer', 'show', 'show_start', 'show_end', 'status', 'charend',
#        'years_since', 'lead', 'support', 'shows', 'score', 'scorey',
#        'lead_notes', 'support_notes', 'show_notes'],
#       dtype='object')

# %% [markdown]
# ####  Subset the data where the status of the show is not "END" or "End."

# %%
# Out:
# END     202
# LEFT     29
# End      17
# Name: status, dtype: int64

# %% [markdown]
# #### Subset the resultant dataframe where the  show start date is after 2011

# %%
# Out:
#                performer            show  show_start show_end status  charend  \
# 232         Michael Gill  House of Cards        2013  PRESENT   LEFT     2014
# 233  Matthew McConaughey  True Detective        2014  PRESENT   LEFT     2014
# 234      Woody Harrelson  True Detective        2014  PRESENT   LEFT     2014
# 235    Michelle Monaghan  True Detective        2014  PRESENT   LEFT     2014
# 236        Michael Potts  True Detective        2014  PRESENT   LEFT     2014
#
#      years_since  lead  support  shows  score scorey
# 232            1     0        0      0    0.0      0
# 233            1     1        0      0    1.0      1
# 234            1     0        2      0    0.5    0.5
# 235            1     4        0      0    4.0      4
# 236            1     0        0      0    0.0      0

# %% [markdown]
# #### Print out the [unique](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html) performers

# %%
# Out:
# array(['Steven Hill', 'Kelli Williams', 'LisaGay Hamilton',
#        'Lara Flynn Boyle', 'Dylan McDermott', 'Camryn Manheim',
#        'Steve Harris', 'Marla Sokoloff', 'Jerry Orbach',
#        'Michael Badalucco', 'Michael C. Hall', 'Joe Mantegna',
#        'Peter Krause', 'Rachel Griffiths', 'Jason Ritter',
#        'Freddy RodrÕguez', 'Frances Conroy', 'Lauren Ambrose',
#        'Amber Tamblyn', 'Justina Machado', 'Mary Steenburgen',
#        'Mathew St. Patrick', 'Michael Welch', 'Aaron Himelstein',
#        'Becky Wahlstrom', 'Chris Marquette', 'Mageina Tovah', 'Rob Lowe',
#        'Dul_ Hill', 'Dayton Callie', 'Timothy Olyphant', 'Joshua Malina',
#        'Anna Gunn', 'Allison Janney', 'Drea de Matteo', 'Paula Malcomson',
#        'Leon Rippy', 'Kim Dickens', 'Bradley Whitford', 'Molly Parker',
#        'William Sanderson', 'Sean Bridgers', 'Richard Schiff',
#        'Ian McShane', 'John Hawkes', 'Robin Weigert', 'Jim Beaver',
# ...

# %% [markdown]
# ####  Select the performer and show columns for rows with index 20-25 (inclusive)

# %%
# Out:
#              performer             show
# 20    Mary Steenburgen  Joan of Arcadia
# 21  Mathew St. Patrick   Six Feet Under
# 22       Michael Welch  Joan of Arcadia
# 23    Aaron Himelstein  Joan of Arcadia
# 24     Becky Wahlstrom  Joan of Arcadia
# 25     Chris Marquette  Joan of Arcadia

# %%
# Out:
#           performer          show  show_start show_end status  charend  \
# 0       Steven Hill   Law & Order        1990     2010    END     2000
# 1    Kelli Williams  The Practice        1997     2014    END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014    END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014    END     2003
# 4   Dylan McDermott  The Practice        1997     2014    END     2004
#
#    years_since  lead  support  shows  score       scorey  \
# 0           15     0        0      0   0.00            0
# 1           12     0        1      6   6.25  0.520833333
# 2           12     2        0      2   4.00  0.333333333
# 3           12     0        0      0   0.00            0
# 4           11     2        7      6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# 2  Life of a King, 2014; Go For Sisters, 2013
# ...

# %% [markdown]
# #### Plot a histogram of score.

# %% [markdown]
# #### Find the nulls values in the dataframe

# %% [markdown]
# #### Drop the columns that have nulls

# %% [markdown]
# #### Create a correlation heatmap for the remaining columns

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ### B. Explore San Francisco Crime Data
#
# ---
#
# #### Load the San Francisco crime data set into a DataFrame.

# %%
crime= pd.read_csv('data/sf_crime.csv')

# %% [markdown]
# #### Look at the dimensions of the crime data.

# %% [markdown]
# #### Look at the data types of the columns and print out the column names.

# %% [markdown]
# #### What is the number of _distinct_ districts?

# %% [markdown]
# #### What are the names of those _distinct_ districts?

# %% [markdown]
# ####  Which day of the week has the most crime?

# %% [markdown]
# #### Find all the rows that have a '/' in the category column

# %% [markdown]
# #### Make a new DataFrame featuring the crime categories and the number of crimes per category.
